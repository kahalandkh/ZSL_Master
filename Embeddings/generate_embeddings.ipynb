# %% [markdown]
# Generate, save, and load embeddings for different models and activity description variants.

# %%
import sys
sys.path.append('..')

import numpy as np

from Embeddings.Models.embedding_generator import EmbeddingGenerator
from Embeddings.Semantics.descriptions import DESCRIPTION_TYPES, get_descriptions

# %%
DESCRIPTION_TYPES.keys()
# Out:
# dict_keys(['original', 'short', 'medium', 'specific', 'noisy', 'random_unrelated', 'detailed_technical', 'very_long'])

# %%
print("Available description types:")
for desc_type in DESCRIPTION_TYPES:
    descriptions = get_descriptions(desc_type)
    print(f"\n{desc_type.upper()}:")
    print(f"Example: {list(descriptions.values())[0]}")
# Out:
# Available description types:
#
# ORIGINAL:
# Example: The person drinks water from a glass or bottle to quench thirst, usually done in a kitchen or dining area. The person lifts the container to their mouth and tilts it to let the water flow in, feeling refreshed afterwards.
#
# SHORT:
# Example: drink water
#
# MEDIUM:
# Example: Drinks water from a glass or bottle, lifting it to their mouth and tilting to drink, usually in kitchen/dining area.
#
# SPECIFIC:
# Example: Lifting a glass or water bottle to the lips and tilting it backward to drink in a kitchen or at a dining table.
#
# NOISY:
# Example: The persn drink watter from glas or botle to quensh thurst, usally in kitchn or dining area lol. Lift container to mout and tilt it, water flow in and feel refreash afters.
#
# RANDOM_UNRELATED:
# Example: Heavy cumulonimbus clouds release intense bursts of lightning across the evening sky during a summer thunderstorm.
#
# DETAILED_TECHNICAL:
# Example: The individual elevates a cylindrical vessel containing H2O to the oral cavity, initiating a controlled tilt to facilitate fluid ingestion via pharyngeal swallowing, primarily engaging deltoid and biceps brachii muscles in a domestic hydration zone.
#
# VERY_LONG:
# Example: In the cozy confines of a sunlit kitchen or a warmly lit dining area, where the faint aroma of freshly brewed coffee lingers in the air and the hum of a refrigerator provides a subtle background noise, the person feels the parched dryness in their throat signaling an urgent need to quench their thirst. They reach for a clear glass or a chilled plastic bottle filled with cool, refreshing water, the condensation on its surface leaving a slight dampness on their fingertips as they grasp it firmly. With deliberate care, they lift the container slowly towards their lips, feeling the weight shift as the liquid inside sloshes gently against the sides. Tilting their head back slightly, they angle the rim to their mouth, allowing the crisp, pure water to flow in a steady stream over their tongue, tasting its neutral, revitalizing essence that instantly soothes the dryness. As they swallow, a wave of coolness travels down their esophagus, spreading a sense of hydration throughout their body. Lowering the container, they exhale softly, feeling the immediate relief and a renewed energy, perhaps wiping away a stray droplet from their chin with the back of their hand, the overall experience leaving them invigorated and ready to continue their day.

# %% [markdown]
# ### Generate embeddings

# %%
generator = EmbeddingGenerator(output_dir='../Data/Embeddings/')

# %%
# Uncomment to generate and save embeddings for all models and description types

results = {}

for model in generator.MODELS:
    for desc_type, descriptions in DESCRIPTION_TYPES.items():
        print(f"\nModel: {model}")
        print(f"Description type: {desc_type}")
        
        descriptions = get_descriptions(desc_type)
        embeddings, filepath = generator.generate_and_save(
            descriptions, model, desc_type, use_prompt=True)

        if model.startswith("clip"):
            key = f"{model.replace('/', '_').replace('-', '_').lower()}_{desc_type}"
        else:
            key = f"{model.split('/')[-1]}_{desc_type}"
        results[key] = embeddings
# Out:
# Model: all-MiniLM-L6-v2
# Description type: original
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_original_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: short
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_short_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: medium
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_medium_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: specific
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_specific_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: noisy
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_noisy_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: random_unrelated
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_random_unrelated_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: detailed_technical
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_detailed_technical_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L6-v2
# Description type: very_long
# Loading model: all-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l6_v2_very_long_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-mpnet-base-v2
# Description type: original
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_original_prompt.npz
# Shape: (24, 768)
# File size: 68.1 KB
#
# Model: all-mpnet-base-v2
# Description type: short
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_short_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: all-mpnet-base-v2
# Description type: medium
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_medium_prompt.npz
# Shape: (24, 768)
# File size: 68.1 KB
#
# Model: all-mpnet-base-v2
# Description type: specific
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_specific_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: all-mpnet-base-v2
# Description type: noisy
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_noisy_prompt.npz
# Shape: (24, 768)
# File size: 68.1 KB
#
# Model: all-mpnet-base-v2
# Description type: random_unrelated
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_random_unrelated_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: all-mpnet-base-v2
# Description type: detailed_technical
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_detailed_technical_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: all-mpnet-base-v2
# Description type: very_long
# Loading model: all-mpnet-base-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_mpnet_base_v2_very_long_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: all-MiniLM-L12-v2
# Description type: original
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_original_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L12-v2
# Description type: short
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_short_prompt.npz
# Shape: (24, 384)
# File size: 34.4 KB
#
# Model: all-MiniLM-L12-v2
# Description type: medium
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_medium_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L12-v2
# Description type: specific
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_specific_prompt.npz
# Shape: (24, 384)
# File size: 34.4 KB
#
# Model: all-MiniLM-L12-v2
# Description type: noisy
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_noisy_prompt.npz
# Shape: (24, 384)
# File size: 34.4 KB
#
# Model: all-MiniLM-L12-v2
# Description type: random_unrelated
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_random_unrelated_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L12-v2
# Description type: detailed_technical
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_detailed_technical_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: all-MiniLM-L12-v2
# Description type: very_long
# Loading model: all-MiniLM-L12-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/all_minilm_l12_v2_very_long_prompt.npz
# Shape: (24, 384)
# File size: 34.4 KB
#
# Model: clip-ViT-B/32
# Description type: original
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_original_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: short
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_short_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: medium
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_medium_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: specific
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_specific_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: noisy
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_noisy_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: random_unrelated
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_random_unrelated_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: detailed_technical
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_detailed_technical_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-B/32
# Description type: very_long
# Loading model: clip-ViT-B/32
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_b_32_very_long_prompt.npz
# Shape: (24, 512)
# File size: 45.7 KB
#
# Model: clip-ViT-L/14
# Description type: original
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_original_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: short
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_short_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: medium
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_medium_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: specific
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_specific_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: noisy
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_noisy_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: random_unrelated
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_random_unrelated_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: detailed_technical
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_detailed_technical_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: clip-ViT-L/14
# Description type: very_long
# Loading model: clip-ViT-L/14
# Generating CLIP embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/clip_vit_l_14_very_long_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: hkunlp/instructor-large
# Description type: original
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_original_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: hkunlp/instructor-large
# Description type: short
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_short_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: hkunlp/instructor-large
# Description type: medium
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_medium_prompt.npz
# Shape: (24, 768)
# File size: 67.9 KB
#
# Model: hkunlp/instructor-large
# Description type: specific
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_specific_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: hkunlp/instructor-large
# Description type: noisy
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_noisy_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: hkunlp/instructor-large
# Description type: random_unrelated
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_random_unrelated_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: hkunlp/instructor-large
# Description type: detailed_technical
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_detailed_technical_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: hkunlp/instructor-large
# Description type: very_long
# Loading model: hkunlp/instructor-large
# Generating Instructor embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/hkunlp_instructor_large_very_long_prompt.npz
# Shape: (24, 768)
# File size: 67.8 KB
#
# Model: bert-base-uncased
# Description type: original
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_original_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: bert-base-uncased
# Description type: short
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_short_prompt.npz
# Shape: (24, 768)
# File size: 68.1 KB
#
# Model: bert-base-uncased
# Description type: medium
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_medium_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: bert-base-uncased
# Description type: specific
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_specific_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: bert-base-uncased
# Description type: noisy
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_noisy_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: bert-base-uncased
# Description type: random_unrelated
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_random_unrelated_prompt.npz
# Shape: (24, 768)
# File size: 68.1 KB
#
# Model: bert-base-uncased
# Description type: detailed_technical
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_detailed_technical_prompt.npz
# Shape: (24, 768)
# File size: 68.0 KB
#
# Model: bert-base-uncased
# Description type: very_long
# Loading model: bert-base-uncased
# Generating BERT embeddings for 24 activities...
# Saved embeddings to: ../Data/Embeddings/bert_base_uncased_very_long_prompt.npz
# Shape: (24, 768)
# File size: 68.1 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: original
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_original_prompt.npz
# Shape: (24, 384)
# File size: 34.4 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: short
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_short_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: medium
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_medium_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: specific
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_specific_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: noisy
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_noisy_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: random_unrelated
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_random_unrelated_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: detailed_technical
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_detailed_technical_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
#
# Model: paraphrase-MiniLM-L6-v2
# Description type: very_long
# Loading model: paraphrase-MiniLM-L6-v2
# Generating Sentence-Transformer embeddings for 24 activities...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved embeddings to: ../Data/Embeddings/paraphrase_minilm_l6_v2_very_long_prompt.npz
# Shape: (24, 384)
# File size: 34.5 KB
